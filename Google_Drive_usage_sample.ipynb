# %% [markdown]
# <a href="https://colab.research.google.com/github/debad777/sjcu-test/blob/main/Google_Drive_usage_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 나의 Google Drive에 있는 File 을 Colab 에서 사용하는 방법
# 1. Colab 에서 Google Drive 를 Gdrive 로 Mount 한다. ( 여기서 "Gdrive" 은 원하는 어떤 이름도 가능함)

# %%
from google.colab import drive
drive.mount('Gdrive')

# %% [markdown]
# 2. File 을 읽어본다 ( 읽기전 나의 Google Drive 해당 Folder 에 해당  File 이 있는지  Google Drive 에서 확인한다.)

# %%
import pandas as pd
df = pd.read_csv('Gdrive/My Drive/eda-datavis/w2/housepricedata.csv')

# %% [markdown]
# 3. 읽은 File 내용을 출력한다.

# %%
df
